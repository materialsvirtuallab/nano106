# %% [markdown]
# # Introduction
#
# In this notebook, we will use Python Materials Genomics (pymatgen), written by Professor Shyue Ping Ong, to data mine the Materials Project (http://www.materialsproject.org) for statistics on space groups. The Materials Project is a large database containing computed data on all inorganic materials. Unlike other large databases, the Materials Project employs a structure matching algorithm to perform duplicate structure filtering. This allows for a more robust statistical analysis.

# %%
from pymatgen import MPRester, Composition
from pymatgen.util.plotting_utils import get_publication_quality_plot
import numpy as np
from prettytable import PrettyTable
from symmetry.groups import sg_name_from_int_number

# %% [markdown]
# Let us use pymatgen's MPRester to query for all formulas and spacegroup information using the Materials Project's RESTful API.

# %%
m = MPRester()
data = m.mpquery({}, ["pretty_formula", "spacegroup.number"])

# %% [markdown]
# ## Distribution of Space Groups
#
# We will now perform a simple histogram analysis of the distribution of space groups.

# %%
sgnums = [d["spacegroup.number"] for d in data]
plt = get_publication_quality_plot(12, 8)
n, bins, patches = plt.hist(sgnums, bins=np.arange(0.5, 231.5, 1), normed=True)
plt.xlim([0, 231])
plt.xlabel("International Space Group No.")
plt.ylabel("Fraction of Compounds")
plt.show()

# %% [markdown]
# ## Most and least common Space Groups
#
# Let's get the most common and least common spacegroups.

# %%
def make_table(hist_data, reverse=False):
    table = PrettyTable(["Int Num", "Int Symbol", "% of total crystals"])
    for i in sorted(range(1, 231), key=lambda i: hist_data[i - 1], reverse=reverse)[0:20]:
        name = sg_name_from_int_number(i)
        table.add_row([i, name, "%.3f" % (hist_data[i - 1] * 100)])    
    return table

print "Most Common Space Groups"
print make_table(n, True)
print
print "Least Common Space Groups"
print make_table(n, False)
# Out:
# Most Common Space Groups
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    14   |  P12_1/c1  |        9.872        |
# |    2    |    P-1     |        6.348        |
# |    62   |    Pnma    |        6.213        |
# |    1    |     P1     |        5.735        |
# |    15   |   C12/c1   |        4.325        |
# |    12   |   C12/m1   |        3.651        |
# |   225   |   Fm-3m    |        2.874        |
# |   139   |   I4/mmm   |        2.762        |
# |   221   |   Pm-3m    |        2.308        |
# |   194   |  P6_3/mmc  |        2.306        |
# |    63   |    Cmcm    |        2.285        |
# |   166   |    R-3m    |        2.137        |
# |    11   |  P12_1/m1  |        1.815        |
# |   227   |   Fd-3m    |        1.616        |
# |    4    |   P12_11   |        1.498        |
# |    8    |    C1m1    |        1.418        |
# |   148   |    R-3     |        1.313        |
# |   216   |   F-43m    |        1.292        |
# |   129   |   P4/nmm   |        1.172        |
# |   164   |   P-3m1    |        1.111        |
# +---------+------------+---------------------+
#
# Least Common Space Groups
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    89   |    P422    |        0.000        |
# |    93   |   P4_222   |        0.000        |
# |   101   |   P4_2cm   |        0.000        |
# |   168   |     P6     |        0.000        |
# |   171   |    P6_2    |        0.000        |
# |   207   |    P432    |        0.000        |
# |   209   |    F432    |        0.000        |
# |    90   |   P42_12   |        0.002        |
# |   103   |    P4cc    |        0.002        |
# |   153   |   P3_212   |        0.002        |
# |   172   |    P6_4    |        0.002        |
# |   210   |   F4_132   |        0.002        |
# |   211   |    I432    |        0.002        |
# |   222   |   Pn-3n    |        0.002        |
# |    77   |    P4_2    |        0.004        |
# |    94   |  P4_22_12  |        0.004        |
# |   106   |   P4_2bc   |        0.004        |
# |   112   |   P-42c    |        0.004        |
# |   175   |    P6/m    |        0.004        |
# |   179   |   P6_522   |        0.004        |
# +---------+------------+---------------------+

# %% [markdown]
# Compare the results above with the tables provided in "Properties of Materials: Anisotropy, Symmetry, Structure" by Robert E. Newnham.

# %% [markdown]
# # More advanced analysis
#
# Let us now go beyond just simple histogrammic analysis and look at the statistics for specific chemistries. For example, we can ask the question - does oxides, sulfides, fluorides and chlorides prefer different space groups? Let us first group the data by the most electronegative element - a proxy of whether it is an oxide, fluoride, etc.

# %%
def get_chemistry(d):
    anion = sorted(Composition(d["pretty_formula"]).keys(), key=lambda el: el.X)[-1].symbol
    if anion == "O":
        return "Oxide"
    if anion == "S":
        return "Sulfide"
    elif anion == "F":
        return "Fluoride"
    elif anion == "Cl":
        return "Chloride"
    return "Others"

import itertools
sdata = sorted(data, key=get_chemistry)
grouped_data = {chem: list(d) for chem, d in itertools.groupby(sdata, key=get_chemistry)}

# %%
def print_table(chemistry):
    sgnums = [d["spacegroup.number"] for d in grouped_data[chemistry]]
    hist, bins = np.histogram(sgnums, bins=np.arange(0.5, 231.5, 1), normed=True)
    print "Most Common Space Groups in %d %ss" % (len(sgnums), chemistry)
    print make_table(hist, True)
    print
    print "Least Common Space Groups in %d %ss" % (len(sgnums), chemistry)
    print make_table(hist, False)

# %% [markdown]
# ### Space Group Distribution in Oxides

# %%
print_table("Oxide")
# Out:
# Most Common Space Groups in 24975 Oxides
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    14   |  P12_1/c1  |        12.663       |
# |    2    |    P-1     |        9.267        |
# |    1    |     P1     |        8.470        |
# |    15   |   C12/c1   |        5.599        |
# |    62   |    Pnma    |        5.270        |
# |    12   |   C12/m1   |        4.141        |
# |    4    |   P12_11   |        2.283        |
# |    11   |  P12_1/m1  |        2.275        |
# |    8    |    C1m1    |        2.066        |
# |   166   |    R-3m    |        1.758        |
# |    5    |    C121    |        1.666        |
# |    33   |   Pna2_1   |        1.542        |
# |   148   |    R-3     |        1.454        |
# |    63   |    Cmcm    |        1.434        |
# |    9    |    C1c1    |        1.418        |
# |    19   | P2_12_121  |        1.414        |
# |   227   |   Fd-3m    |        1.394        |
# |    61   |    Pbca    |        1.237        |
# |    7    |    P1c1    |        1.197        |
# |   139   |   I4/mmm   |        1.069        |
# +---------+------------+---------------------+
#
# Least Common Space Groups in 24975 Oxides
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    89   |    P422    |        0.000        |
# |    93   |   P4_222   |        0.000        |
# |   101   |   P4_2cm   |        0.000        |
# |   104   |    P4nc    |        0.000        |
# |   112   |   P-42c    |        0.000        |
# |   153   |   P3_212   |        0.000        |
# |   168   |     P6     |        0.000        |
# |   171   |    P6_2    |        0.000        |
# |   207   |    P432    |        0.000        |
# |   209   |    F432    |        0.000        |
# |    23   |    I222    |        0.004        |
# |    48   |    Pnnn    |        0.004        |
# |    77   |    P4_2    |        0.004        |
# |    90   |   P42_12   |        0.004        |
# |    97   |    I422    |        0.004        |
# |   103   |    P4cc    |        0.004        |
# |   116   |   P-4c2    |        0.004        |
# |   132   |  P4_2/mcm  |        0.004        |
# |   172   |    P6_4    |        0.004        |
# |   175   |    P6/m    |        0.004        |
# +---------+------------+---------------------+

# %% [markdown]
# **We can see that oxides have an even higher prevalence of the monoclinic $P12_1/c1$ and triclinc $P\overline{1}$ space groups, compared to the overall distribution for all compounds.**

# %% [markdown]
# ### Space Group Distribution in Sulfides

# %%
print_table("Sulfide")
# Out:
# Most Common Space Groups in 2514 Sulfides
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    62   |    Pnma    |        8.801        |
# |    14   |  P12_1/c1  |        8.195        |
# |    15   |   C12/c1   |        4.481        |
# |    12   |   C12/m1   |        4.360        |
# |   122   |   I-42d    |        4.360        |
# |   166   |    R-3m    |        3.956        |
# |    1    |     P1     |        3.432        |
# |    2    |    P-1     |        3.432        |
# |   227   |   Fd-3m    |        2.584        |
# |    63   |    Cmcm    |        2.382        |
# |   160   |    R3m     |        2.301        |
# |    11   |  P12_1/m1  |        2.059        |
# |   194   |  P6_3/mmc  |        2.059        |
# |   156   |    P3m1    |        1.776        |
# |   225   |   Fm-3m    |        1.655        |
# |   173   |    P6_3    |        1.615        |
# |    9    |    C1c1    |        1.494        |
# |   164   |   P-3m1    |        1.413        |
# |    70   |    Fddd    |        1.332        |
# |   148   |    R-3     |        1.292        |
# +---------+------------+---------------------+
#
# Least Common Space Groups in 2514 Sulfides
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    3    |    P121    |        0.000        |
# |    21   |    C222    |        0.000        |
# |    22   |    F222    |        0.000        |
# |    24   | I2_12_121  |        0.000        |
# |    27   |    Pcc2    |        0.000        |
# |    28   |    Pma2    |        0.000        |
# |    30   |    Pnc2    |        0.000        |
# |    32   |    Pba2    |        0.000        |
# |    35   |    Cmm2    |        0.000        |
# |    45   |    Iba2    |        0.000        |
# |    47   |    Pmmm    |        0.000        |
# |    48   |    Pnnn    |        0.000        |
# |    52   |    Pnna    |        0.000        |
# |    53   |    Pmna    |        0.000        |
# |    68   |    Ccca    |        0.000        |
# |    75   |     P4     |        0.000        |
# |    76   |    P4_1    |        0.000        |
# |    78   |    P4_3    |        0.000        |
# |    80   |    I4_1    |        0.000        |
# |    83   |    P4/m    |        0.000        |
# +---------+------------+---------------------+

# %% [markdown]
# **The distribution for sulfides is quite different. Now, the orthorhombic $Pnma$ is the most prevalent. In general, it seems that sulfides tend to have higher-symmetry structures that oxides (space group numbers are generally larger).**

# %% [markdown]
# ### Space Group Distribution in Fluorides

# %%
print_table("Fluoride")
# Out:
# Most Common Space Groups in 4676 Fluorides
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    14   |  P12_1/c1  |        13.024       |
# |    1    |     P1     |        9.837        |
# |    2    |    P-1     |        7.506        |
# |    62   |    Pnma    |        6.009        |
# |    15   |   C12/c1   |        4.876        |
# |    12   |   C12/m1   |        3.272        |
# |   225   |   Fm-3m    |        2.908        |
# |   148   |    R-3     |        2.481        |
# |    8    |    C1m1    |        1.903        |
# |    4    |   P12_11   |        1.796        |
# |    6    |    P1m1    |        1.775        |
# |   166   |    R-3m    |        1.732        |
# |    9    |    C1c1    |        1.668        |
# |    63   |    Cmcm    |        1.625        |
# |    19   | P2_12_121  |        1.497        |
# |    33   |   Pna2_1   |        1.454        |
# |    11   |  P12_1/m1  |        1.433        |
# |   139   |   I4/mmm   |        1.369        |
# |    5    |    C121    |        1.283        |
# |   129   |   P4/nmm   |        1.283        |
# +---------+------------+---------------------+
#
# Least Common Space Groups in 4676 Fluorides
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    16   |    P222    |        0.000        |
# |    23   |    I222    |        0.000        |
# |    24   | I2_12_121  |        0.000        |
# |    27   |    Pcc2    |        0.000        |
# |    28   |    Pma2    |        0.000        |
# |    37   |    Ccc2    |        0.000        |
# |    45   |    Iba2    |        0.000        |
# |    48   |    Pnnn    |        0.000        |
# |    49   |    Pccm    |        0.000        |
# |    50   |    Pban    |        0.000        |
# |    66   |    Cccm    |        0.000        |
# |    75   |     P4     |        0.000        |
# |    77   |    P4_2    |        0.000        |
# |    80   |    I4_1    |        0.000        |
# |    83   |    P4/m    |        0.000        |
# |    89   |    P422    |        0.000        |
# |    90   |   P42_12   |        0.000        |
# |    93   |   P4_222   |        0.000        |
# |    94   |  P4_22_12  |        0.000        |
# |    96   |  P4_32_12  |        0.000        |
# +---------+------------+---------------------+

# %% [markdown]
# **Again, we see that fluorides seem to have a similar distribution as the oxides, with a higher than average prevalence of the monoclinic $P12_1/c1$ and triclinc $P\overline{1}$ space groups.**

# %% [markdown]
# ### Space Group Distribution in Chlorides

# %%
print_table("Chloride")
# Out:
# Most Common Space Groups in 1451 Chlorides
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    14   |  P12_1/c1  |        15.379       |
# |    62   |    Pnma    |        8.759        |
# |    2    |    P-1     |        6.966        |
# |   225   |   Fm-3m    |        5.862        |
# |    15   |   C12/c1   |        5.379        |
# |    12   |   C12/m1   |        4.414        |
# |   166   |    R-3m    |        2.621        |
# |    61   |    Pbca    |        2.345        |
# |    11   |  P12_1/m1  |        2.138        |
# |   148   |    R-3     |        2.138        |
# |   194   |  P6_3/mmc  |        2.000        |
# |   164   |   P-3m1    |        1.655        |
# |    63   |    Cmcm    |        1.448        |
# |    33   |   Pna2_1   |        1.379        |
# |   139   |   I4/mmm   |        1.379        |
# |   176   |   P6_3/m   |        1.379        |
# |    1    |     P1     |        1.310        |
# |    64   |    Cmca    |        1.241        |
# |   205   |    Pa-3    |        1.172        |
# |    13   |   P12/c1   |        1.034        |
# +---------+------------+---------------------+
#
# Least Common Space Groups in 1451 Chlorides
# +---------+------------+---------------------+
# | Int Num | Int Symbol | % of total crystals |
# +---------+------------+---------------------+
# |    16   |    P222    |        0.000        |
# |    17   |   P222_1   |        0.000        |
# |    21   |    C222    |        0.000        |
# |    22   |    F222    |        0.000        |
# |    23   |    I222    |        0.000        |
# |    24   | I2_12_121  |        0.000        |
# |    25   |    Pmm2    |        0.000        |
# |    27   |    Pcc2    |        0.000        |
# |    30   |    Pnc2    |        0.000        |
# |    32   |    Pba2    |        0.000        |
# |    34   |    Pnn2    |        0.000        |
# |    35   |    Cmm2    |        0.000        |
# |    37   |    Ccc2    |        0.000        |
# |    41   |    Aba2    |        0.000        |
# |    47   |    Pmmm    |        0.000        |
# |    48   |    Pnnn    |        0.000        |
# |    49   |    Pccm    |        0.000        |
# |    50   |    Pban    |        0.000        |
# |    53   |    Pmna    |        0.000        |
# |    54   |    Pcca    |        0.000        |
# +---------+------------+---------------------+

# %% [markdown]
# **Though not as stark as the comparison between oxides and sulfides, we also observe that chlorides tend to have higher prevalence of high-symmetry spacegroups than fluorides.**

# %% [markdown]
# # Conclusion
#
# In this notebook, we have done some basic analysis of prevalence of space groups in inorganic crystals in the Materials Project and detailed analysis for some common chemistries. We find that sulfides tend to have higher prevalence of high-symmetry space groups compared to oxides, and a similar trend is observed chlorides versus fluorides. Though we cannot make firm conclusions based on just these few data points, it does suggest that larger anion sizes lead to higher-symmetry crystals.
